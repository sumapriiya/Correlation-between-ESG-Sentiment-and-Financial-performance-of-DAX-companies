# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.13.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 5.5 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 43.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 36.0 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 512 kB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 43.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.13.0

# %% [markdown]
# **Read in the Excel file - Validation set**

# %%
import pandas as pd 
df = pd.read_excel('/content/drive/MyDrive/Equintel/esg_sentiment_data.xlsx')

# %% [markdown]
# **Perform Sentiment Analysis using transformers making use of the Distilbert Model**

# %%
from transformers import pipeline

classifier = pipeline('sentiment-analysis',model = 'distilbert-base-uncased-finetuned-sst-2-english')

distilbert = []
for str in df['title']: 
  distilbert.append(classifier(str))
df['distilbert']=distilbert
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %% [markdown]
# **Update the predicted sentiment and score of the sentiment to the Excel sheet**

# %%
distilbert_sentiment = []
distilbert_score = []
for row in df['distilbert']:
  if row[0]['label'] == 'POSITIVE':
    distilbert_sentiment.append(1) 
  else:
    distilbert_sentiment.append(0)
  distilbert_score.append(row[0]['score'])
df['distilbert_sentiment'] = distilbert_sentiment
df['distilbert_score'] = distilbert_score
df.to_excel('/content/drive/MyDrive/Equintel/esg_sentiment_data_updated_081221.xlsx')

# %% [markdown]
# **Check the number of incorrect predictions **

# %%
distil_var_count = 0
for index,row in df.iterrows(): 
  if (row['automated_sentiment'] != row['distilbert_sentiment']):
      distil_var_count+=1

print(distil_var_count)
# Out:
# 3439

# %% [markdown]
# **Perform Sentiment Analysis using transformers making use of the Bert Model**

# %%
classifier = pipeline('sentiment-analysis', model="nlptown/bert-base-multilingual-uncased-sentiment")

# %%
bert = []
for str in df['title']: 
  bert.append(classifier(str))
  print(classifier(str))
df['bert']=bert
# Out:
# Streaming output truncated to the last 5000 lines.
# [{'label': '1 star', 'score': 0.5034287571907043}]
# [{'label': '3 stars', 'score': 0.5636187791824341}]
# [{'label': '5 stars', 'score': 0.4061442017555237}]
# [{'label': '1 star', 'score': 0.23594602942466736}]
# [{'label': '1 star', 'score': 0.34920018911361694}]
# [{'label': '1 star', 'score': 0.6839644908905029}]
# [{'label': '5 stars', 'score': 0.396517813205719}]
# [{'label': '5 stars', 'score': 0.45534491539001465}]
# [{'label': '5 stars', 'score': 0.8207956552505493}]
# [{'label': '5 stars', 'score': 0.626349687576294}]
# [{'label': '5 stars', 'score': 0.6014477014541626}]
# [{'label': '5 stars', 'score': 0.3126126527786255}]
# [{'label': '5 stars', 'score': 0.5577641129493713}]
# [{'label': '1 star', 'score': 0.4783870577812195}]
# [{'label': '4 stars', 'score': 0.2714894413948059}]
# [{'label': '1 star', 'score': 0.44749394059181213}]
# [{'label': '1 star', 'score': 0.6418935656547546}]
# [{'label': '1 star', 'score': 0.3602082133293152}]
# [{'label': '1 star', 'score': 0.48789647221565247}]
# [{'label': '5 stars', 'score': 0.5124151706695557}]
# [{'label': '1 star', 'score': 0.23684179782867432}]
# [{'label': '5 stars', 'score': 0.4062236249446869}]
# [{'label': '1 star', 'score': 0.29258331656455994}]
# [{'label': '5 stars', 'score': 0.6952525973320007}]
# [{'label': '1 star', 'score': 0.4590473175048828}]
# [{'label': '3 stars', 'score': 0.24510104954242706}]
# [{'label': '1 star', 'score': 0.4612967073917389}]
# [{'label': '4 stars', 'score': 0.3766474723815918}]
# [{'label': '5 stars', 'score': 0.4020542502403259}]
# [{'label': '5 stars', 'score': 0.3552214801311493}]
# [{'label': '1 star', 'score': 0.3994717001914978}]
# [{'label': '5 stars', 'score': 0.7173007130622864}]
# [{'label': '4 stars', 'score': 0.3813806474208832}]
# [{'label': '5 stars', 'score': 0.5531921982765198}]
# [{'label': '1 star', 'score': 0.7511597871780396}]
# [{'label': '1 star', 'score': 0.37267863750457764}]
# [{'label': '4 stars', 'score': 0.2404242604970932}]
# [{'label': '4 stars', 'score': 0.37169408798217773}]
# [{'label': '5 stars', 'score': 0.5386027693748474}]
# [{'label': '1 star', 'score': 0.7175999283790588}]
# [{'label': '1 star', 'score': 0.22989365458488464}]
# [{'label': '1 star', 'score': 0.40136295557022095}]
# [{'label': '5 stars', 'score': 0.2494203746318817}]
# [{'label': '1 star', 'score': 0.30124393105506897}]
# [{'label': '1 star', 'score': 0.5603378415107727}]
# [{'label': '1 star', 'score': 0.7325894236564636}]
# [{'label': '5 stars', 'score': 0.6525373458862305}]
# [{'label': '5 stars', 'score': 0.26675641536712646}]
# [{'label': '2 stars', 'score': 0.29511338472366333}]
# [{'label': '1 star', 'score': 0.426098495721817}]
# [{'label': '2 stars', 'score': 0.24853646755218506}]
# [{'label': '5 stars', 'score': 0.4491349160671234}]
# [{'label': '5 stars', 'score': 0.4957555830478668}]
# [{'label': '1 star', 'score': 0.28819146752357483}]
# [{'label': '1 star', 'score': 0.3031350076198578}]
# [{'label': '5 stars', 'score': 0.5010230541229248}]
# [{'label': '5 stars', 'score': 0.4847146272659302}]
# [{'label': '5 stars', 'score': 0.2980513572692871}]
# [{'label': '1 star', 'score': 0.39666685461997986}]
# [{'label': '1 star', 'score': 0.5713046789169312}]
# [{'label': '5 stars', 'score': 0.4260352551937103}]
# [{'label': '3 stars', 'score': 0.37862280011177063}]
# [{'label': '5 stars', 'score': 0.3906220495700836}]
# [{'label': '1 star', 'score': 0.4371914267539978}]
# [{'label': '1 star', 'score': 0.281721293926239}]
# [{'label': '5 stars', 'score': 0.3634456992149353}]
# [{'label': '5 stars', 'score': 0.4219501316547394}]
# [{'label': '5 stars', 'score': 0.3571457266807556}]
# [{'label': '1 star', 'score': 0.4081336259841919}]
# [{'label': '1 star', 'score': 0.5086642503738403}]
# [{'label': '4 stars', 'score': 0.34705621004104614}]
# [{'label': '4 stars', 'score': 0.2437569797039032}]
# [{'label': '5 stars', 'score': 0.3889561593532562}]
# [{'label': '5 stars', 'score': 0.31161510944366455}]
# [{'label': '5 stars', 'score': 0.6493827104568481}]
# [{'label': '5 stars', 'score': 0.7617964744567871}]
# [{'label': '1 star', 'score': 0.567122757434845}]
# [{'label': '5 stars', 'score': 0.2250232696533203}]
# [{'label': '5 stars', 'score': 0.48898065090179443}]
# [{'label': '3 stars', 'score': 0.284676194190979}]
# [{'label': '5 stars', 'score': 0.38379549980163574}]
# [{'label': '1 star', 'score': 0.5342580080032349}]
# [{'label': '5 stars', 'score': 0.41945093870162964}]
# [{'label': '5 stars', 'score': 0.5643129348754883}]
# [{'label': '4 stars', 'score': 0.3015342354774475}]
# [{'label': '5 stars', 'score': 0.386292964220047}]
# [{'label': '5 stars', 'score': 0.45339345932006836}]
# [{'label': '1 star', 'score': 0.698118269443512}]
# [{'label': '4 stars', 'score': 0.397762268781662}]
# [{'label': '4 stars', 'score': 0.2536981701850891}]
# [{'label': '1 star', 'score': 0.5283815860748291}]
# [{'label': '1 star', 'score': 0.6846993565559387}]
# [{'label': '5 stars', 'score': 0.5503131151199341}]
# [{'label': '5 stars', 'score': 0.3431398272514343}]
# [{'label': '2 stars', 'score': 0.4177270233631134}]
# [{'label': '1 star', 'score': 0.5183020234107971}]
# [{'label': '2 stars', 'score': 0.28820323944091797}]
# [{'label': '1 star', 'score': 0.37553665041923523}]
# [{'label': '1 star', 'score': 0.3761144280433655}]
# [{'label': '3 stars', 'score': 0.42057642340660095}]
# [{'label': '5 stars', 'score': 0.49068963527679443}]
# [{'label': '5 stars', 'score': 0.5278270244598389}]
# [{'label': '5 stars', 'score': 0.3252791166305542}]
# [{'label': '5 stars', 'score': 0.40704840421676636}]
# [{'label': '5 stars', 'score': 0.521536648273468}]
# [{'label': '1 star', 'score': 0.48941680788993835}]
# [{'label': '5 stars', 'score': 0.3661445081233978}]
# [{'label': '5 stars', 'score': 0.46155181527137756}]
# [{'label': '5 stars', 'score': 0.4761720597743988}]
# [{'label': '1 star', 'score': 0.6221372485160828}]
# [{'label': '5 stars', 'score': 0.6589802503585815}]
# [{'label': '1 star', 'score': 0.6451025605201721}]
# [{'label': '5 stars', 'score': 0.4337022304534912}]
# [{'label': '4 stars', 'score': 0.2748822271823883}]
# [{'label': '5 stars', 'score': 0.3536547124385834}]
# [{'label': '5 stars', 'score': 0.4639092683792114}]
# [{'label': '4 stars', 'score': 0.38233181834220886}]
# [{'label': '1 star', 'score': 0.601867139339447}]
# [{'label': '5 stars', 'score': 0.6472771763801575}]
# [{'label': '5 stars', 'score': 0.49767792224884033}]
# [{'label': '5 stars', 'score': 0.5285609364509583}]
# [{'label': '4 stars', 'score': 0.4198977053165436}]
# [{'label': '1 star', 'score': 0.7291855216026306}]
# [{'label': '4 stars', 'score': 0.25620701909065247}]
# [{'label': '1 star', 'score': 0.7746760249137878}]
# [{'label': '1 star', 'score': 0.39531436562538147}]
# [{'label': '1 star', 'score': 0.5655112862586975}]
# [{'label': '1 star', 'score': 0.724851131439209}]
# [{'label': '5 stars', 'score': 0.33544600009918213}]
# [{'label': '5 stars', 'score': 0.44435369968414307}]
# [{'label': '5 stars', 'score': 0.49198800325393677}]
# [{'label': '1 star', 'score': 0.6889041066169739}]
# [{'label': '1 star', 'score': 0.26427823305130005}]
# [{'label': '5 stars', 'score': 0.5249502062797546}]
# [{'label': '1 star', 'score': 0.4364255666732788}]
# [{'label': '5 stars', 'score': 0.47514697909355164}]
# [{'label': '4 stars', 'score': 0.3543899953365326}]
# [{'label': '5 stars', 'score': 0.5201779007911682}]
# [{'label': '1 star', 'score': 0.3824027478694916}]
# [{'label': '1 star', 'score': 0.40121960639953613}]
# [{'label': '1 star', 'score': 0.26253440976142883}]
# [{'label': '1 star', 'score': 0.6774383783340454}]
# [{'label': '1 star', 'score': 0.7568679451942444}]
# [{'label': '5 stars', 'score': 0.46580833196640015}]
# [{'label': '1 star', 'score': 0.4731612801551819}]
# [{'label': '1 star', 'score': 0.26506638526916504}]
# [{'label': '4 stars', 'score': 0.29779455065727234}]
# [{'label': '1 star', 'score': 0.29961997270584106}]
# [{'label': '5 stars', 'score': 0.3162727355957031}]
# [{'label': '1 star', 'score': 0.5843458771705627}]
# [{'label': '1 star', 'score': 0.24997252225875854}]
# [{'label': '1 star', 'score': 0.293922483921051}]
# [{'label': '4 stars', 'score': 0.3627622127532959}]
# [{'label': '1 star', 'score': 0.6100775003433228}]
# [{'label': '5 stars', 'score': 0.4676511287689209}]
# [{'label': '1 star', 'score': 0.24589596688747406}]
# [{'label': '4 stars', 'score': 0.3592747449874878}]
# [{'label': '5 stars', 'score': 0.40575727820396423}]
# [{'label': '2 stars', 'score': 0.367235004901886}]
# [{'label': '1 star', 'score': 0.5899554491043091}]
# [{'label': '5 stars', 'score': 0.49753740429878235}]
# [{'label': '5 stars', 'score': 0.39282262325286865}]
# [{'label': '5 stars', 'score': 0.4873781204223633}]
# [{'label': '1 star', 'score': 0.3849274218082428}]
# [{'label': '4 stars', 'score': 0.35258132219314575}]
# [{'label': '1 star', 'score': 0.5684727430343628}]
# [{'label': '5 stars', 'score': 0.3094403147697449}]
# [{'label': '1 star', 'score': 0.6559795141220093}]
# [{'label': '5 stars', 'score': 0.2804946005344391}]
# [{'label': '2 stars', 'score': 0.3781965374946594}]
# [{'label': '5 stars', 'score': 0.6391370296478271}]
# [{'label': '4 stars', 'score': 0.30063676834106445}]
# [{'label': '1 star', 'score': 0.4923970401287079}]
# [{'label': '1 star', 'score': 0.5657270550727844}]
# [{'label': '1 star', 'score': 0.45489540696144104}]
# [{'label': '1 star', 'score': 0.24850378930568695}]
# [{'label': '5 stars', 'score': 0.3867998421192169}]
# [{'label': '5 stars', 'score': 0.507915198802948}]
# [{'label': '1 star', 'score': 0.47663643956184387}]
# [{'label': '4 stars', 'score': 0.2562716603279114}]
# [{'label': '1 star', 'score': 0.31608694791793823}]
# [{'label': '1 star', 'score': 0.3849942088127136}]
# [{'label': '5 stars', 'score': 0.2760173976421356}]
# [{'label': '5 stars', 'score': 0.5376001000404358}]
# [{'label': '3 stars', 'score': 0.2734801769256592}]
# [{'label': '1 star', 'score': 0.612330973148346}]
# [{'label': '1 star', 'score': 0.7591845393180847}]
# [{'label': '5 stars', 'score': 0.42123183608055115}]
# [{'label': '5 stars', 'score': 0.662215530872345}]
# [{'label': '4 stars', 'score': 0.3367191553115845}]
# [{'label': '4 stars', 'score': 0.3741864860057831}]
# [{'label': '5 stars', 'score': 0.4643470048904419}]
# [{'label': '1 star', 'score': 0.3009142279624939}]
# [{'label': '2 stars', 'score': 0.24535614252090454}]
# [{'label': '5 stars', 'score': 0.4494955241680145}]
# [{'label': '1 star', 'score': 0.7558770179748535}]
# [{'label': '5 stars', 'score': 0.5007715225219727}]
# [{'label': '4 stars', 'score': 0.33815014362335205}]
# [{'label': '5 stars', 'score': 0.7126556634902954}]
# [{'label': '1 star', 'score': 0.7637627124786377}]
# [{'label': '1 star', 'score': 0.37685802578926086}]
# [{'label': '3 stars', 'score': 0.38977256417274475}]
# [{'label': '4 stars', 'score': 0.41563916206359863}]
# [{'label': '5 stars', 'score': 0.3795013129711151}]
# [{'label': '4 stars', 'score': 0.23305293917655945}]
# [{'label': '1 star', 'score': 0.5285711884498596}]
# [{'label': '5 stars', 'score': 0.6965817213058472}]
# [{'label': '1 star', 'score': 0.7391268610954285}]
# [{'label': '1 star', 'score': 0.4744095802307129}]
# [{'label': '4 stars', 'score': 0.3667598366737366}]
# [{'label': '5 stars', 'score': 0.6450507640838623}]
# [{'label': '1 star', 'score': 0.7387443780899048}]
# [{'label': '5 stars', 'score': 0.4274280071258545}]
# [{'label': '1 star', 'score': 0.502898633480072}]
# [{'label': '4 stars', 'score': 0.33250048756599426}]
# [{'label': '5 stars', 'score': 0.5632105469703674}]
# [{'label': '1 star', 'score': 0.6523996591567993}]
# [{'label': '5 stars', 'score': 0.613309383392334}]
# [{'label': '5 stars', 'score': 0.6181482672691345}]
# [{'label': '5 stars', 'score': 0.31464284658432007}]
# [{'label': '5 stars', 'score': 0.3576558232307434}]
# [{'label': '2 stars', 'score': 0.3119055926799774}]
# [{'label': '1 star', 'score': 0.36084115505218506}]
# [{'label': '1 star', 'score': 0.26901140809059143}]
# [{'label': '1 star', 'score': 0.6680169701576233}]
# [{'label': '4 stars', 'score': 0.4589122235774994}]
# [{'label': '5 stars', 'score': 0.4236850142478943}]
# [{'label': '1 star', 'score': 0.47879183292388916}]
# [{'label': '1 star', 'score': 0.23210659623146057}]
# [{'label': '5 stars', 'score': 0.44651639461517334}]
# [{'label': '4 stars', 'score': 0.31173306703567505}]
# [{'label': '1 star', 'score': 0.2534266710281372}]
# [{'label': '1 star', 'score': 0.5540720820426941}]
# [{'label': '5 stars', 'score': 0.6480116248130798}]
# [{'label': '1 star', 'score': 0.7801540493965149}]
# [{'label': '1 star', 'score': 0.4630165100097656}]
# [{'label': '1 star', 'score': 0.5702489614486694}]
# [{'label': '4 stars', 'score': 0.36277592182159424}]
# [{'label': '5 stars', 'score': 0.4409334063529968}]
# [{'label': '1 star', 'score': 0.5482121109962463}]
# [{'label': '1 star', 'score': 0.642730176448822}]
# [{'label': '5 stars', 'score': 0.46779102087020874}]
# [{'label': '5 stars', 'score': 0.5743067860603333}]
# [{'label': '5 stars', 'score': 0.6172534823417664}]
# [{'label': '5 stars', 'score': 0.39596083760261536}]
# [{'label': '1 star', 'score': 0.3632960021495819}]
# [{'label': '1 star', 'score': 0.6864244341850281}]
# [{'label': '2 stars', 'score': 0.310684472322464}]
# [{'label': '5 stars', 'score': 0.455178827047348}]
# [{'label': '4 stars', 'score': 0.25469911098480225}]
# [{'label': '1 star', 'score': 0.3303767740726471}]
# [{'label': '5 stars', 'score': 0.428558349609375}]
# [{'label': '1 star', 'score': 0.5711402893066406}]
# [{'label': '5 stars', 'score': 0.39054590463638306}]
# [{'label': '5 stars', 'score': 0.41973286867141724}]
# [{'label': '4 stars', 'score': 0.30852010846138}]
# [{'label': '4 stars', 'score': 0.2879354953765869}]
# [{'label': '1 star', 'score': 0.30216389894485474}]
# [{'label': '5 stars', 'score': 0.4569709300994873}]
# [{'label': '5 stars', 'score': 0.3702945411205292}]
# [{'label': '4 stars', 'score': 0.44742703437805176}]
# [{'label': '4 stars', 'score': 0.3075818717479706}]
# [{'label': '5 stars', 'score': 0.30982667207717896}]
# [{'label': '5 stars', 'score': 0.45311349630355835}]
# [{'label': '4 stars', 'score': 0.43396759033203125}]
# [{'label': '5 stars', 'score': 0.7338321208953857}]
# [{'label': '1 star', 'score': 0.4484250247478485}]
# [{'label': '5 stars', 'score': 0.36279794573783875}]
# [{'label': '1 star', 'score': 0.6839644908905029}]
# [{'label': '1 star', 'score': 0.3710120618343353}]
# [{'label': '1 star', 'score': 0.2517314851284027}]
# [{'label': '5 stars', 'score': 0.7601552605628967}]
# [{'label': '5 stars', 'score': 0.5829517245292664}]
# [{'label': '5 stars', 'score': 0.44241294264793396}]
# [{'label': '5 stars', 'score': 0.807895302772522}]
# [{'label': '5 stars', 'score': 0.35794350504875183}]
# [{'label': '4 stars', 'score': 0.4321501851081848}]
# [{'label': '4 stars', 'score': 0.37626367807388306}]
# [{'label': '5 stars', 'score': 0.4403455853462219}]
# [{'label': '3 stars', 'score': 0.2527525722980499}]
# [{'label': '5 stars', 'score': 0.39310258626937866}]
# [{'label': '1 star', 'score': 0.31259429454803467}]
# [{'label': '1 star', 'score': 0.6491474509239197}]
# [{'label': '5 stars', 'score': 0.6162962913513184}]
# [{'label': '1 star', 'score': 0.4686957597732544}]
# [{'label': '4 stars', 'score': 0.3457358777523041}]
# [{'label': '1 star', 'score': 0.41200703382492065}]
# [{'label': '1 star', 'score': 0.3384474813938141}]
# [{'label': '4 stars', 'score': 0.4273141026496887}]
# [{'label': '5 stars', 'score': 0.34704941511154175}]
# [{'label': '1 star', 'score': 0.2723267674446106}]
# [{'label': '5 stars', 'score': 0.4647253155708313}]
# [{'label': '5 stars', 'score': 0.38197392225265503}]
# [{'label': '3 stars', 'score': 0.3418382406234741}]
# [{'label': '5 stars', 'score': 0.4859832227230072}]
# [{'label': '1 star', 'score': 0.5760082006454468}]
# [{'label': '5 stars', 'score': 0.4267304837703705}]
# [{'label': '4 stars', 'score': 0.24174796044826508}]
# [{'label': '1 star', 'score': 0.38187459111213684}]
# [{'label': '5 stars', 'score': 0.5878832936286926}]
# [{'label': '5 stars', 'score': 0.4767739176750183}]
# [{'label': '5 stars', 'score': 0.7112165093421936}]
# [{'label': '3 stars', 'score': 0.2746923267841339}]
# [{'label': '4 stars', 'score': 0.419117271900177}]
# [{'label': '5 stars', 'score': 0.701410710811615}]
# [{'label': '1 star', 'score': 0.8863036632537842}]
# [{'label': '4 stars', 'score': 0.33980149030685425}]
# [{'label': '5 stars', 'score': 0.6207602024078369}]
# [{'label': '1 star', 'score': 0.45281508564949036}]
# [{'label': '5 stars', 'score': 0.5261574387550354}]
# [{'label': '1 star', 'score': 0.39412182569503784}]
# [{'label': '5 stars', 'score': 0.695163905620575}]
# [{'label': '5 stars', 'score': 0.3901436924934387}]
# [{'label': '5 stars', 'score': 0.43499016761779785}]
# [{'label': '1 star', 'score': 0.7276621460914612}]
# [{'label': '1 star', 'score': 0.7321595549583435}]
# [{'label': '1 star', 'score': 0.3195344805717468}]
# [{'label': '5 stars', 'score': 0.36206087470054626}]
# [{'label': '5 stars', 'score': 0.37144631147384644}]
# [{'label': '1 star', 'score': 0.35820814967155457}]
# [{'label': '5 stars', 'score': 0.4629357159137726}]
# [{'label': '5 stars', 'score': 0.4295792877674103}]
# [{'label': '1 star', 'score': 0.36739230155944824}]
# [{'label': '5 stars', 'score': 0.39860016107559204}]
# [{'label': '1 star', 'score': 0.23073811829090118}]
# [{'label': '5 stars', 'score': 0.2668543756008148}]
# [{'label': '1 star', 'score': 0.36384695768356323}]
# [{'label': '5 stars', 'score': 0.4809648394584656}]
# [{'label': '5 stars', 'score': 0.4652768671512604}]
# [{'label': '5 stars', 'score': 0.5826039910316467}]
# [{'label': '1 star', 'score': 0.490217924118042}]
# [{'label': '1 star', 'score': 0.45793360471725464}]
# [{'label': '5 stars', 'score': 0.32318374514579773}]
# [{'label': '5 stars', 'score': 0.3714304566383362}]
# [{'label': '1 star', 'score': 0.3823871910572052}]
# [{'label': '5 stars', 'score': 0.5208718776702881}]
# [{'label': '1 star', 'score': 0.52619868516922}]
# [{'label': '5 stars', 'score': 0.5693872570991516}]
# [{'label': '5 stars', 'score': 0.4874667227268219}]
# [{'label': '1 star', 'score': 0.40276890993118286}]
# [{'label': '1 star', 'score': 0.8746110796928406}]
# [{'label': '5 stars', 'score': 0.37648916244506836}]
# [{'label': '5 stars', 'score': 0.3127260208129883}]
# [{'label': '1 star', 'score': 0.5659387707710266}]
# [{'label': '1 star', 'score': 0.7420376539230347}]
# [{'label': '1 star', 'score': 0.5977210998535156}]
# [{'label': '4 stars', 'score': 0.3964563012123108}]
# [{'label': '1 star', 'score': 0.7574865818023682}]
# [{'label': '1 star', 'score': 0.46703651547431946}]
# [{'label': '1 star', 'score': 0.289580374956131}]
# [{'label': '4 stars', 'score': 0.32150158286094666}]
# [{'label': '1 star', 'score': 0.4605477750301361}]
# [{'label': '2 stars', 'score': 0.3523769676685333}]
# [{'label': '4 stars', 'score': 0.29375481605529785}]
# [{'label': '3 stars', 'score': 0.22353726625442505}]
# [{'label': '5 stars', 'score': 0.7115679383277893}]
# [{'label': '4 stars', 'score': 0.2622053027153015}]
# [{'label': '5 stars', 'score': 0.3026462197303772}]
# [{'label': '2 stars', 'score': 0.34362658858299255}]
# [{'label': '5 stars', 'score': 0.6432264447212219}]
# [{'label': '5 stars', 'score': 0.24064916372299194}]
# [{'label': '1 star', 'score': 0.4444948434829712}]
# [{'label': '4 stars', 'score': 0.3259352147579193}]
# [{'label': '1 star', 'score': 0.2669798731803894}]
# [{'label': '2 stars', 'score': 0.26685425639152527}]
# [{'label': '1 star', 'score': 0.34376955032348633}]
# [{'label': '1 star', 'score': 0.32968011498451233}]
# [{'label': '1 star', 'score': 0.4887620210647583}]
# [{'label': '1 star', 'score': 0.6575813889503479}]
# [{'label': '1 star', 'score': 0.5763197541236877}]
# [{'label': '5 stars', 'score': 0.6243628263473511}]
# [{'label': '1 star', 'score': 0.6391083002090454}]
# [{'label': '4 stars', 'score': 0.35182690620422363}]
# [{'label': '4 stars', 'score': 0.260475218296051}]
# [{'label': '1 star', 'score': 0.28423115611076355}]
# [{'label': '4 stars', 'score': 0.3691040277481079}]
# [{'label': '5 stars', 'score': 0.605666995048523}]
# [{'label': '4 stars', 'score': 0.3357152044773102}]
# [{'label': '5 stars', 'score': 0.5260341763496399}]
# [{'label': '1 star', 'score': 0.6195663809776306}]
# [{'label': '1 star', 'score': 0.3484143018722534}]
# [{'label': '4 stars', 'score': 0.3109426498413086}]
# [{'label': '5 stars', 'score': 0.6237788796424866}]
# [{'label': '5 stars', 'score': 0.2863956689834595}]
# [{'label': '5 stars', 'score': 0.5768958330154419}]
# [{'label': '1 star', 'score': 0.6680766344070435}]
# [{'label': '4 stars', 'score': 0.24798229336738586}]
# [{'label': '1 star', 'score': 0.5547005534172058}]
# [{'label': '5 stars', 'score': 0.5848889946937561}]
# [{'label': '5 stars', 'score': 0.7310743927955627}]
# [{'label': '1 star', 'score': 0.43606826663017273}]
# [{'label': '2 stars', 'score': 0.33748289942741394}]
# [{'label': '1 star', 'score': 0.4785936772823334}]
# [{'label': '1 star', 'score': 0.8386113047599792}]
# [{'label': '1 star', 'score': 0.36653590202331543}]
# [{'label': '4 stars', 'score': 0.45053187012672424}]
# [{'label': '4 stars', 'score': 0.4794710576534271}]
# [{'label': '1 star', 'score': 0.7367935180664062}]
# [{'label': '5 stars', 'score': 0.2515595257282257}]
# [{'label': '4 stars', 'score': 0.4681919813156128}]
# [{'label': '4 stars', 'score': 0.3766474723815918}]
# [{'label': '1 star', 'score': 0.7503383755683899}]
# [{'label': '5 stars', 'score': 0.39134883880615234}]
# [{'label': '3 stars', 'score': 0.23585154116153717}]
# [{'label': '4 stars', 'score': 0.24657222628593445}]
# [{'label': '1 star', 'score': 0.3040061295032501}]
# [{'label': '1 star', 'score': 0.7305784821510315}]
# [{'label': '5 stars', 'score': 0.4517478942871094}]
# [{'label': '1 star', 'score': 0.6008107662200928}]
# [{'label': '1 star', 'score': 0.4174959361553192}]
# [{'label': '1 star', 'score': 0.5226662158966064}]
# [{'label': '5 stars', 'score': 0.5074480175971985}]
# [{'label': '1 star', 'score': 0.3632124066352844}]
# [{'label': '1 star', 'score': 0.6181536912918091}]
# [{'label': '5 stars', 'score': 0.33449310064315796}]
# [{'label': '5 stars', 'score': 0.617241621017456}]
# [{'label': '1 star', 'score': 0.4040980637073517}]
# [{'label': '4 stars', 'score': 0.3366374969482422}]
# [{'label': '1 star', 'score': 0.5853991508483887}]
# [{'label': '5 stars', 'score': 0.4760032892227173}]
# [{'label': '5 stars', 'score': 0.3684692084789276}]
# [{'label': '4 stars', 'score': 0.2531595826148987}]
# [{'label': '2 stars', 'score': 0.23018886148929596}]
# [{'label': '1 star', 'score': 0.3876003921031952}]
# [{'label': '5 stars', 'score': 0.41132616996765137}]
# [{'label': '1 star', 'score': 0.6054554581642151}]
# [{'label': '4 stars', 'score': 0.4642913341522217}]
# [{'label': '5 stars', 'score': 0.45917755365371704}]
# [{'label': '5 stars', 'score': 0.2623523473739624}]
# [{'label': '1 star', 'score': 0.579303503036499}]
# [{'label': '5 stars', 'score': 0.7883555889129639}]
# [{'label': '1 star', 'score': 0.32676321268081665}]
# [{'label': '5 stars', 'score': 0.6048297882080078}]
# [{'label': '5 stars', 'score': 0.39061951637268066}]
# [{'label': '5 stars', 'score': 0.5285554528236389}]
# [{'label': '5 stars', 'score': 0.5574016571044922}]
# [{'label': '1 star', 'score': 0.42232900857925415}]
# [{'label': '1 star', 'score': 0.6793816089630127}]
# [{'label': '4 stars', 'score': 0.4389086365699768}]
# [{'label': '1 star', 'score': 0.35545480251312256}]
# [{'label': '5 stars', 'score': 0.38386473059654236}]
# [{'label': '1 star', 'score': 0.497692734003067}]
# [{'label': '1 star', 'score': 0.35261136293411255}]
# [{'label': '1 star', 'score': 0.35121282935142517}]
# [{'label': '4 stars', 'score': 0.45569565892219543}]
# [{'label': '5 stars', 'score': 0.5025477409362793}]
# [{'label': '3 stars', 'score': 0.33519503474235535}]
# [{'label': '5 stars', 'score': 0.4136773347854614}]
# [{'label': '2 stars', 'score': 0.3133392930030823}]
# [{'label': '3 stars', 'score': 0.3415699303150177}]
# [{'label': '1 star', 'score': 0.4365253746509552}]
# [{'label': '1 star', 'score': 0.6363458633422852}]
# [{'label': '1 star', 'score': 0.6114888191223145}]
# [{'label': '1 star', 'score': 0.35918551683425903}]
# [{'label': '4 stars', 'score': 0.35309967398643494}]
# [{'label': '1 star', 'score': 0.34173598885536194}]
# [{'label': '1 star', 'score': 0.31237107515335083}]
# [{'label': '5 stars', 'score': 0.31386563181877136}]
# [{'label': '1 star', 'score': 0.340951144695282}]
# [{'label': '5 stars', 'score': 0.5500762462615967}]
# [{'label': '5 stars', 'score': 0.6945127248764038}]
# [{'label': '2 stars', 'score': 0.29325807094573975}]
# [{'label': '5 stars', 'score': 0.39469772577285767}]
# [{'label': '4 stars', 'score': 0.4296257197856903}]
# [{'label': '5 stars', 'score': 0.4321940541267395}]
# [{'label': '4 stars', 'score': 0.43316686153411865}]
# [{'label': '1 star', 'score': 0.4303957223892212}]
# [{'label': '3 stars', 'score': 0.3990304470062256}]
# [{'label': '4 stars', 'score': 0.2557528018951416}]
# [{'label': '5 stars', 'score': 0.28395697474479675}]
# [{'label': '1 star', 'score': 0.4839635491371155}]
# [{'label': '1 star', 'score': 0.5004279017448425}]
# [{'label': '1 star', 'score': 0.5175155401229858}]
# [{'label': '5 stars', 'score': 0.3200361430644989}]
# [{'label': '1 star', 'score': 0.7816636562347412}]
# [{'label': '5 stars', 'score': 0.5763137340545654}]
# [{'label': '1 star', 'score': 0.5906033515930176}]
# [{'label': '1 star', 'score': 0.28465884923934937}]
# [{'label': '1 star', 'score': 0.6071822047233582}]
# [{'label': '4 stars', 'score': 0.26848387718200684}]
# [{'label': '5 stars', 'score': 0.5023460388183594}]
# [{'label': '4 stars', 'score': 0.24971003830432892}]
# [{'label': '1 star', 'score': 0.6095634698867798}]
# [{'label': '4 stars', 'score': 0.319754958152771}]
# [{'label': '2 stars', 'score': 0.29349765181541443}]
# [{'label': '1 star', 'score': 0.580190122127533}]
# [{'label': '5 stars', 'score': 0.3965320289134979}]
# [{'label': '1 star', 'score': 0.4235273003578186}]
# [{'label': '1 star', 'score': 0.6530218124389648}]
# [{'label': '5 stars', 'score': 0.678693950176239}]
# [{'label': '1 star', 'score': 0.5411009788513184}]
# [{'label': '5 stars', 'score': 0.39612212777137756}]
# [{'label': '5 stars', 'score': 0.49612730741500854}]
# [{'label': '5 stars', 'score': 0.48895683884620667}]
# [{'label': '1 star', 'score': 0.7322105169296265}]
# [{'label': '5 stars', 'score': 0.5179585814476013}]
# [{'label': '4 stars', 'score': 0.3844152092933655}]
# [{'label': '5 stars', 'score': 0.3479296565055847}]
# [{'label': '1 star', 'score': 0.6872545480728149}]
# [{'label': '5 stars', 'score': 0.32691970467567444}]
# [{'label': '1 star', 'score': 0.6462936997413635}]
# [{'label': '1 star', 'score': 0.7013459205627441}]
# [{'label': '4 stars', 'score': 0.3842153251171112}]
# [{'label': '1 star', 'score': 0.37789493799209595}]
# [{'label': '5 stars', 'score': 0.3684692084789276}]
# [{'label': '1 star', 'score': 0.6344905495643616}]
# [{'label': '1 star', 'score': 0.23398131132125854}]
# [{'label': '1 star', 'score': 0.5596253871917725}]
# [{'label': '5 stars', 'score': 0.5823412537574768}]
# [{'label': '1 star', 'score': 0.4645361006259918}]
# [{'label': '5 stars', 'score': 0.3241192400455475}]
# [{'label': '1 star', 'score': 0.7254631519317627}]
# [{'label': '1 star', 'score': 0.761142373085022}]
# [{'label': '5 stars', 'score': 0.7301763296127319}]
# [{'label': '5 stars', 'score': 0.4666619598865509}]
# [{'label': '1 star', 'score': 0.3949686586856842}]
# [{'label': '4 stars', 'score': 0.3396270275115967}]
# [{'label': '1 star', 'score': 0.4515568017959595}]
# [{'label': '5 stars', 'score': 0.32726237177848816}]
# [{'label': '5 stars', 'score': 0.3467092514038086}]
# [{'label': '5 stars', 'score': 0.5756711363792419}]
# [{'label': '5 stars', 'score': 0.5749275088310242}]
# [{'label': '1 star', 'score': 0.7428230047225952}]
# [{'label': '4 stars', 'score': 0.33434462547302246}]
# [{'label': '1 star', 'score': 0.4389781057834625}]
# [{'label': '1 star', 'score': 0.6439114809036255}]
# [{'label': '1 star', 'score': 0.5098981261253357}]
# [{'label': '1 star', 'score': 0.5618956685066223}]
# [{'label': '2 stars', 'score': 0.36901530623435974}]
# [{'label': '1 star', 'score': 0.3204977810382843}]
# [{'label': '5 stars', 'score': 0.3126126527786255}]
# [{'label': '5 stars', 'score': 0.27778539061546326}]
# [{'label': '5 stars', 'score': 0.5860554575920105}]
# [{'label': '5 stars', 'score': 0.6197145581245422}]
# [{'label': '5 stars', 'score': 0.5903911590576172}]
# [{'label': '1 star', 'score': 0.33618324995040894}]
# [{'label': '1 star', 'score': 0.3694348931312561}]
# [{'label': '1 star', 'score': 0.3426218628883362}]
# [{'label': '4 stars', 'score': 0.329374223947525}]
# [{'label': '1 star', 'score': 0.5175155401229858}]
# [{'label': '1 star', 'score': 0.3507838547229767}]
# [{'label': '1 star', 'score': 0.4915502071380615}]
# [{'label': '3 stars', 'score': 0.31312522292137146}]
# [{'label': '1 star', 'score': 0.327470988035202}]
# [{'label': '5 stars', 'score': 0.31716910004615784}]
# [{'label': '5 stars', 'score': 0.7369109392166138}]
# [{'label': '4 stars', 'score': 0.4189847707748413}]
# [{'label': '5 stars', 'score': 0.4628506898880005}]
# [{'label': '5 stars', 'score': 0.3497447371482849}]
# [{'label': '1 star', 'score': 0.6134880781173706}]
# [{'label': '1 star', 'score': 0.5639100670814514}]
# [{'label': '1 star', 'score': 0.550064206123352}]
# [{'label': '3 stars', 'score': 0.3527628183364868}]
# [{'label': '5 stars', 'score': 0.46225932240486145}]
# [{'label': '5 stars', 'score': 0.3239421546459198}]
# [{'label': '4 stars', 'score': 0.4068058729171753}]
# [{'label': '1 star', 'score': 0.28723064064979553}]
# [{'label': '1 star', 'score': 0.6854281425476074}]
# [{'label': '4 stars', 'score': 0.3091602027416229}]
# [{'label': '5 stars', 'score': 0.47782739996910095}]
# [{'label': '1 star', 'score': 0.6680169701576233}]
# [{'label': '1 star', 'score': 0.2729674279689789}]
# [{'label': '5 stars', 'score': 0.402863472700119}]
# [{'label': '1 star', 'score': 0.7349571585655212}]
# [{'label': '5 stars', 'score': 0.5847154259681702}]
# [{'label': '5 stars', 'score': 0.26207587122917175}]
# [{'label': '5 stars', 'score': 0.39853301644325256}]
# [{'label': '5 stars', 'score': 0.2554895877838135}]
# [{'label': '1 star', 'score': 0.270884245634079}]
# [{'label': '3 stars', 'score': 0.344838947057724}]
# [{'label': '5 stars', 'score': 0.5353208780288696}]
# [{'label': '5 stars', 'score': 0.45356032252311707}]
# [{'label': '1 star', 'score': 0.3926471471786499}]
# [{'label': '5 stars', 'score': 0.4100153148174286}]
# [{'label': '5 stars', 'score': 0.5600500702857971}]
# [{'label': '3 stars', 'score': 0.2811497151851654}]
# [{'label': '1 star', 'score': 0.5208077430725098}]
# [{'label': '1 star', 'score': 0.8313639163970947}]
# [{'label': '4 stars', 'score': 0.4140463173389435}]
# [{'label': '5 stars', 'score': 0.5204527974128723}]
# [{'label': '4 stars', 'score': 0.2903718948364258}]
# [{'label': '5 stars', 'score': 0.3748772442340851}]
# [{'label': '5 stars', 'score': 0.47394877672195435}]
# [{'label': '5 stars', 'score': 0.43216660618782043}]
# [{'label': '5 stars', 'score': 0.49669939279556274}]
# [{'label': '1 star', 'score': 0.5775578618049622}]
# [{'label': '1 star', 'score': 0.24880141019821167}]
# [{'label': '1 star', 'score': 0.5805922150611877}]
# [{'label': '5 stars', 'score': 0.2547425329685211}]
# [{'label': '5 stars', 'score': 0.38720792531967163}]
# [{'label': '4 stars', 'score': 0.2716289460659027}]
# [{'label': '1 star', 'score': 0.4587181806564331}]
# [{'label': '1 star', 'score': 0.7262369990348816}]
# [{'label': '1 star', 'score': 0.35922959446907043}]
# [{'label': '5 stars', 'score': 0.5214820504188538}]
# [{'label': '3 stars', 'score': 0.37813249230384827}]
# [{'label': '5 stars', 'score': 0.4227384030818939}]
# [{'label': '1 star', 'score': 0.4193606674671173}]
# [{'label': '1 star', 'score': 0.40590977668762207}]
# [{'label': '1 star', 'score': 0.5859670639038086}]
# [{'label': '1 star', 'score': 0.5481232404708862}]
# [{'label': '4 stars', 'score': 0.4169932007789612}]
# [{'label': '5 stars', 'score': 0.5934894680976868}]
# [{'label': '5 stars', 'score': 0.6810234189033508}]
# [{'label': '1 star', 'score': 0.4338987171649933}]
# [{'label': '1 star', 'score': 0.2723148763179779}]
# [{'label': '4 stars', 'score': 0.28166913986206055}]
# [{'label': '1 star', 'score': 0.3755105435848236}]
# [{'label': '5 stars', 'score': 0.509619414806366}]
# [{'label': '5 stars', 'score': 0.4489537179470062}]
# [{'label': '4 stars', 'score': 0.28086066246032715}]
# [{'label': '1 star', 'score': 0.717056393623352}]
# [{'label': '5 stars', 'score': 0.49767792224884033}]
# [{'label': '5 stars', 'score': 0.346835732460022}]
# [{'label': '5 stars', 'score': 0.5563699007034302}]
# [{'label': '1 star', 'score': 0.48177796602249146}]
# [{'label': '1 star', 'score': 0.5677375793457031}]
# [{'label': '4 stars', 'score': 0.4208126962184906}]
# [{'label': '5 stars', 'score': 0.6278466582298279}]
# [{'label': '5 stars', 'score': 0.48437926173210144}]
# [{'label': '1 star', 'score': 0.2630932927131653}]
# [{'label': '4 stars', 'score': 0.2240920066833496}]
# [{'label': '5 stars', 'score': 0.6432264447212219}]
# [{'label': '4 stars', 'score': 0.3141281306743622}]
# [{'label': '1 star', 'score': 0.33433133363723755}]
# [{'label': '1 star', 'score': 0.3413936197757721}]
# [{'label': '1 star', 'score': 0.6266568303108215}]
# [{'label': '5 stars', 'score': 0.41645267605781555}]
# [{'label': '5 stars', 'score': 0.35193338990211487}]
# [{'label': '1 star', 'score': 0.3451104462146759}]
# [{'label': '1 star', 'score': 0.6514597535133362}]
# [{'label': '1 star', 'score': 0.2937619984149933}]
# [{'label': '5 stars', 'score': 0.46580833196640015}]
# [{'label': '1 star', 'score': 0.5925903916358948}]
# [{'label': '4 stars', 'score': 0.2960234582424164}]
# [{'label': '1 star', 'score': 0.5987380146980286}]
# [{'label': '1 star', 'score': 0.6793816089630127}]
# [{'label': '1 star', 'score': 0.47840702533721924}]
# [{'label': '1 star', 'score': 0.5510590672492981}]
# [{'label': '1 star', 'score': 0.8653117418289185}]
# [{'label': '5 stars', 'score': 0.3867419958114624}]
# [{'label': '1 star', 'score': 0.4314858019351959}]
# [{'label': '5 stars', 'score': 0.39429137110710144}]
# [{'label': '5 stars', 'score': 0.6453672051429749}]
# [{'label': '5 stars', 'score': 0.5587251782417297}]
# [{'label': '4 stars', 'score': 0.2475384920835495}]
# [{'label': '5 stars', 'score': 0.4460954964160919}]
# [{'label': '5 stars', 'score': 0.6882616877555847}]
# [{'label': '4 stars', 'score': 0.325180321931839}]
# [{'label': '5 stars', 'score': 0.4067017734050751}]
# [{'label': '5 stars', 'score': 0.6343340277671814}]
# [{'label': '5 stars', 'score': 0.40172871947288513}]
# [{'label': '5 stars', 'score': 0.39469772577285767}]
# [{'label': '1 star', 'score': 0.4937809109687805}]
# [{'label': '2 stars', 'score': 0.3127821981906891}]
# [{'label': '5 stars', 'score': 0.46771955490112305}]
# [{'label': '5 stars', 'score': 0.4429539144039154}]
# [{'label': '5 stars', 'score': 0.3000691831111908}]
# [{'label': '3 stars', 'score': 0.2554873526096344}]
# [{'label': '1 star', 'score': 0.3736812174320221}]
# [{'label': '1 star', 'score': 0.5418506264686584}]
# [{'label': '1 star', 'score': 0.3919398784637451}]
# [{'label': '1 star', 'score': 0.4870067238807678}]
# [{'label': '3 stars', 'score': 0.40912795066833496}]
# [{'label': '1 star', 'score': 0.39327189326286316}]
# [{'label': '5 stars', 'score': 0.367480993270874}]
# [{'label': '5 stars', 'score': 0.49170637130737305}]
# [{'label': '5 stars', 'score': 0.5848889946937561}]
# [{'label': '1 star', 'score': 0.5454174876213074}]
# [{'label': '5 stars', 'score': 0.42790859937667847}]
# [{'label': '4 stars', 'score': 0.34434226155281067}]
# [{'label': '5 stars', 'score': 0.2655125856399536}]
# [{'label': '1 star', 'score': 0.6088974475860596}]
# [{'label': '5 stars', 'score': 0.6497817039489746}]
# [{'label': '4 stars', 'score': 0.3334769904613495}]
# [{'label': '5 stars', 'score': 0.3085537254810333}]
# [{'label': '1 star', 'score': 0.6948602199554443}]
# [{'label': '1 star', 'score': 0.28349727392196655}]
# [{'label': '1 star', 'score': 0.4852169454097748}]
# [{'label': '3 stars', 'score': 0.3026584982872009}]
# [{'label': '1 star', 'score': 0.38187459111213684}]
# [{'label': '5 stars', 'score': 0.35304293036460876}]
# [{'label': '1 star', 'score': 0.561924159526825}]
# [{'label': '1 star', 'score': 0.5104450583457947}]
# [{'label': '1 star', 'score': 0.27460992336273193}]
# [{'label': '5 stars', 'score': 0.4486980736255646}]
# [{'label': '1 star', 'score': 0.4760318100452423}]
# [{'label': '5 stars', 'score': 0.4386002719402313}]
# [{'label': '1 star', 'score': 0.8350147008895874}]
# [{'label': '1 star', 'score': 0.4170910716056824}]
# [{'label': '4 stars', 'score': 0.3042699992656708}]
# [{'label': '1 star', 'score': 0.31771010160446167}]
# [{'label': '5 stars', 'score': 0.8625723123550415}]
# [{'label': '1 star', 'score': 0.3243033289909363}]
# [{'label': '1 star', 'score': 0.6279329061508179}]
# [{'label': '5 stars', 'score': 0.44593337178230286}]
# [{'label': '4 stars', 'score': 0.44816917181015015}]
# [{'label': '3 stars', 'score': 0.28482455015182495}]
# [{'label': '1 star', 'score': 0.6211856007575989}]
# [{'label': '5 stars', 'score': 0.3878598213195801}]
# [{'label': '1 star', 'score': 0.7923547029495239}]
# [{'label': '5 stars', 'score': 0.48439961671829224}]
# [{'label': '1 star', 'score': 0.6064938306808472}]
# [{'label': '5 stars', 'score': 0.4093465507030487}]
# [{'label': '1 star', 'score': 0.7134531140327454}]
# [{'label': '5 stars', 'score': 0.6361966729164124}]
# [{'label': '5 stars', 'score': 0.6699450612068176}]
# [{'label': '4 stars', 'score': 0.24014613032341003}]
# [{'label': '3 stars', 'score': 0.4247327744960785}]
# [{'label': '1 star', 'score': 0.6545498967170715}]
# [{'label': '4 stars', 'score': 0.2775343656539917}]
# [{'label': '5 stars', 'score': 0.7160606980323792}]
# [{'label': '5 stars', 'score': 0.5976178050041199}]
# [{'label': '1 star', 'score': 0.29736295342445374}]
# [{'label': '1 star', 'score': 0.5652719140052795}]
# [{'label': '5 stars', 'score': 0.4325764775276184}]
# [{'label': '1 star', 'score': 0.2877798080444336}]
# [{'label': '1 star', 'score': 0.7698741555213928}]
# [{'label': '5 stars', 'score': 0.2891043424606323}]
# [{'label': '1 star', 'score': 0.7510049939155579}]
# [{'label': '1 star', 'score': 0.5846567153930664}]
# [{'label': '4 stars', 'score': 0.3533461093902588}]
# [{'label': '5 stars', 'score': 0.4354937970638275}]
# [{'label': '5 stars', 'score': 0.43139493465423584}]
# [{'label': '5 stars', 'score': 0.5078555345535278}]
# [{'label': '4 stars', 'score': 0.29134252667427063}]
# [{'label': '5 stars', 'score': 0.4019547700881958}]
# [{'label': '1 star', 'score': 0.316672682762146}]
# [{'label': '4 stars', 'score': 0.3129498362541199}]
# [{'label': '3 stars', 'score': 0.25546520948410034}]
# [{'label': '1 star', 'score': 0.40306976437568665}]
# [{'label': '5 stars', 'score': 0.3409363627433777}]
# [{'label': '1 star', 'score': 0.5979072451591492}]
# [{'label': '1 star', 'score': 0.28662586212158203}]
# [{'label': '4 stars', 'score': 0.28213199973106384}]
# [{'label': '1 star', 'score': 0.6652520895004272}]
# [{'label': '5 stars', 'score': 0.5796734690666199}]
# [{'label': '5 stars', 'score': 0.4569551944732666}]
# [{'label': '4 stars', 'score': 0.787917971611023}]
# [{'label': '5 stars', 'score': 0.6775128841400146}]
# [{'label': '1 star', 'score': 0.28430280089378357}]
# [{'label': '1 star', 'score': 0.304908812046051}]
# [{'label': '1 star', 'score': 0.2463030219078064}]
# [{'label': '4 stars', 'score': 0.49658265709877014}]
# [{'label': '5 stars', 'score': 0.46599769592285156}]
# [{'label': '5 stars', 'score': 0.5577641129493713}]
# [{'label': '5 stars', 'score': 0.35166049003601074}]
# [{'label': '1 star', 'score': 0.8292332887649536}]
# [{'label': '1 star', 'score': 0.5383715033531189}]
# [{'label': '3 stars', 'score': 0.441697895526886}]
# [{'label': '4 stars', 'score': 0.28986650705337524}]
# [{'label': '5 stars', 'score': 0.6238260865211487}]
# [{'label': '5 stars', 'score': 0.5647299885749817}]
# [{'label': '4 stars', 'score': 0.34935450553894043}]
# [{'label': '1 star', 'score': 0.7379404902458191}]
# [{'label': '1 star', 'score': 0.3833109438419342}]
# [{'label': '5 stars', 'score': 0.730801522731781}]
# [{'label': '5 stars', 'score': 0.5046398639678955}]
# [{'label': '1 star', 'score': 0.6515099406242371}]
# [{'label': '5 stars', 'score': 0.653649091720581}]
# [{'label': '1 star', 'score': 0.35162851214408875}]
# [{'label': '1 star', 'score': 0.29904600977897644}]
# [{'label': '1 star', 'score': 0.7171279788017273}]
# [{'label': '1 star', 'score': 0.6102494597434998}]
# [{'label': '1 star', 'score': 0.7287390232086182}]
# [{'label': '4 stars', 'score': 0.2593935430049896}]
# [{'label': '5 stars', 'score': 0.44765016436576843}]
# [{'label': '1 star', 'score': 0.7169530987739563}]
# [{'label': '4 stars', 'score': 0.4036540389060974}]
# [{'label': '5 stars', 'score': 0.4337124228477478}]
# [{'label': '5 stars', 'score': 0.5188435912132263}]
# [{'label': '1 star', 'score': 0.7171512842178345}]
# [{'label': '5 stars', 'score': 0.5477491021156311}]
# [{'label': '5 stars', 'score': 0.5125383138656616}]
# [{'label': '1 star', 'score': 0.7366687655448914}]
# [{'label': '1 star', 'score': 0.7175714373588562}]
# [{'label': '1 star', 'score': 0.2785463035106659}]
# [{'label': '1 star', 'score': 0.274349182844162}]
# [{'label': '3 stars', 'score': 0.2302168607711792}]
# [{'label': '5 stars', 'score': 0.4461367726325989}]
# [{'label': '5 stars', 'score': 0.4745955467224121}]
# [{'label': '5 stars', 'score': 0.309011310338974}]
# [{'label': '5 stars', 'score': 0.3097490072250366}]
# [{'label': '1 star', 'score': 0.4479416012763977}]
# [{'label': '5 stars', 'score': 0.544114887714386}]
# [{'label': '1 star', 'score': 0.3872174918651581}]
# [{'label': '5 stars', 'score': 0.4228682816028595}]
# [{'label': '1 star', 'score': 0.6873122453689575}]
# [{'label': '5 stars', 'score': 0.4617586135864258}]
# [{'label': '5 stars', 'score': 0.503409206867218}]
# [{'label': '5 stars', 'score': 0.2810118794441223}]
# [{'label': '5 stars', 'score': 0.2810118794441223}]
# [{'label': '1 star', 'score': 0.4123956263065338}]
# [{'label': '5 stars', 'score': 0.3830782175064087}]
# [{'label': '1 star', 'score': 0.5122964978218079}]
# [{'label': '1 star', 'score': 0.4282466769218445}]
# [{'label': '3 stars', 'score': 0.38000550866127014}]
# [{'label': '5 stars', 'score': 0.4353657364845276}]
# [{'label': '2 stars', 'score': 0.3573760390281677}]
# [{'label': '5 stars', 'score': 0.568272054195404}]
# [{'label': '5 stars', 'score': 0.2655125856399536}]
# [{'label': '5 stars', 'score': 0.455178827047348}]
# [{'label': '1 star', 'score': 0.4710708260536194}]
# [{'label': '5 stars', 'score': 0.4973343312740326}]
# [{'label': '1 star', 'score': 0.40748149156570435}]
# [{'label': '5 stars', 'score': 0.36230579018592834}]
# [{'label': '5 stars', 'score': 0.4250757098197937}]
# [{'label': '3 stars', 'score': 0.29306530952453613}]
# [{'label': '2 stars', 'score': 0.3815173804759979}]
# [{'label': '5 stars', 'score': 0.39567774534225464}]
# [{'label': '5 stars', 'score': 0.3130151033401489}]
# [{'label': '4 stars', 'score': 0.23696787655353546}]
# [{'label': '5 stars', 'score': 0.47682902216911316}]
# [{'label': '3 stars', 'score': 0.2273399829864502}]
# [{'label': '5 stars', 'score': 0.6146624088287354}]
# [{'label': '5 stars', 'score': 0.428558349609375}]
# [{'label': '3 stars', 'score': 0.29551124572753906}]
# [{'label': '4 stars', 'score': 0.34874463081359863}]
# [{'label': '4 stars', 'score': 0.3988110423088074}]
# [{'label': '5 stars', 'score': 0.4037742018699646}]
# [{'label': '5 stars', 'score': 0.5091131329536438}]
# [{'label': '1 star', 'score': 0.37144535779953003}]
# [{'label': '1 star', 'score': 0.5419099926948547}]
# [{'label': '5 stars', 'score': 0.5078282952308655}]
# [{'label': '4 stars', 'score': 0.4720645546913147}]
# [{'label': '1 star', 'score': 0.28270015120506287}]
# [{'label': '4 stars', 'score': 0.4225291311740875}]
# [{'label': '1 star', 'score': 0.6026871204376221}]
# [{'label': '1 star', 'score': 0.27180662751197815}]
# [{'label': '5 stars', 'score': 0.3353070020675659}]
# [{'label': '5 stars', 'score': 0.5804033279418945}]
# [{'label': '1 star', 'score': 0.43657681345939636}]
# [{'label': '1 star', 'score': 0.5513598918914795}]
# [{'label': '1 star', 'score': 0.3682498335838318}]
# [{'label': '1 star', 'score': 0.5797281861305237}]
# [{'label': '1 star', 'score': 0.5949458479881287}]
# [{'label': '5 stars', 'score': 0.4739990234375}]
# [{'label': '5 stars', 'score': 0.4525482952594757}]
# [{'label': '4 stars', 'score': 0.3680603504180908}]
# [{'label': '1 star', 'score': 0.7565078735351562}]
# [{'label': '5 stars', 'score': 0.39456188678741455}]
# [{'label': '1 star', 'score': 0.6357866525650024}]
# [{'label': '5 stars', 'score': 0.27142053842544556}]
# [{'label': '1 star', 'score': 0.23988278210163116}]
# [{'label': '3 stars', 'score': 0.3215447962284088}]
# [{'label': '1 star', 'score': 0.6933034658432007}]
# [{'label': '1 star', 'score': 0.6808959245681763}]
# [{'label': '1 star', 'score': 0.8825875520706177}]
# [{'label': '1 star', 'score': 0.6779402494430542}]
# [{'label': '1 star', 'score': 0.6148700714111328}]
# [{'label': '5 stars', 'score': 0.6169525980949402}]
# [{'label': '5 stars', 'score': 0.4060194492340088}]
# [{'label': '5 stars', 'score': 0.5923672318458557}]
# [{'label': '1 star', 'score': 0.4450131356716156}]
# [{'label': '5 stars', 'score': 0.5154703855514526}]
# [{'label': '1 star', 'score': 0.27329251170158386}]
# [{'label': '5 stars', 'score': 0.569989800453186}]
# [{'label': '4 stars', 'score': 0.3517172336578369}]
# [{'label': '4 stars', 'score': 0.3486572206020355}]
# [{'label': '1 star', 'score': 0.31566765904426575}]
# [{'label': '5 stars', 'score': 0.6465505361557007}]
# [{'label': '1 star', 'score': 0.319769024848938}]
# [{'label': '1 star', 'score': 0.7823951244354248}]
# [{'label': '1 star', 'score': 0.2578526437282562}]
# [{'label': '4 stars', 'score': 0.3551168441772461}]
# [{'label': '1 star', 'score': 0.5901927351951599}]
# [{'label': '5 stars', 'score': 0.5380505919456482}]
# [{'label': '4 stars', 'score': 0.39441198110580444}]
# [{'label': '1 star', 'score': 0.3867461681365967}]
# [{'label': '1 star', 'score': 0.6584431529045105}]
# [{'label': '1 star', 'score': 0.2688314914703369}]
# [{'label': '1 star', 'score': 0.29500705003738403}]
# [{'label': '5 stars', 'score': 0.304691344499588}]
# [{'label': '5 stars', 'score': 0.4089350700378418}]
# [{'label': '1 star', 'score': 0.7099546194076538}]
# [{'label': '5 stars', 'score': 0.47612395882606506}]
# [{'label': '2 stars', 'score': 0.29257944226264954}]
# [{'label': '4 stars', 'score': 0.27259117364883423}]
# [{'label': '1 star', 'score': 0.7052216529846191}]
# [{'label': '1 star', 'score': 0.46928220987319946}]
# [{'label': '5 stars', 'score': 0.5277404189109802}]
# [{'label': '1 star', 'score': 0.606302797794342}]
# [{'label': '5 stars', 'score': 0.4564053416252136}]
# [{'label': '1 star', 'score': 0.5785312652587891}]
# [{'label': '5 stars', 'score': 0.5861433148384094}]
# [{'label': '5 stars', 'score': 0.5173226594924927}]
# [{'label': '1 star', 'score': 0.5255109071731567}]
# [{'label': '5 stars', 'score': 0.38307908177375793}]
# [{'label': '1 star', 'score': 0.24903477728366852}]
# [{'label': '5 stars', 'score': 0.4014417231082916}]
# [{'label': '5 stars', 'score': 0.5803941488265991}]
# [{'label': '1 star', 'score': 0.6999707221984863}]
# [{'label': '5 stars', 'score': 0.42225053906440735}]
# [{'label': '1 star', 'score': 0.7789526581764221}]
# [{'label': '1 star', 'score': 0.37062570452690125}]
# [{'label': '1 star', 'score': 0.512938380241394}]
# [{'label': '5 stars', 'score': 0.43019333481788635}]
# [{'label': '5 stars', 'score': 0.2518199682235718}]
# [{'label': '1 star', 'score': 0.4956486225128174}]
# [{'label': '5 stars', 'score': 0.4986068308353424}]
# [{'label': '5 stars', 'score': 0.5715556144714355}]
# [{'label': '1 star', 'score': 0.314373642206192}]
# [{'label': '5 stars', 'score': 0.7455707788467407}]
# [{'label': '4 stars', 'score': 0.2974822521209717}]
# [{'label': '3 stars', 'score': 0.2851826548576355}]
# [{'label': '1 star', 'score': 0.5949458479881287}]
# [{'label': '1 star', 'score': 0.5623587965965271}]
# [{'label': '5 stars', 'score': 0.5536638498306274}]
# [{'label': '4 stars', 'score': 0.2592398226261139}]
# [{'label': '3 stars', 'score': 0.3602851927280426}]
# [{'label': '1 star', 'score': 0.5451501607894897}]
# [{'label': '1 star', 'score': 0.48639780282974243}]
# [{'label': '4 stars', 'score': 0.3021850287914276}]
# [{'label': '3 stars', 'score': 0.23317624628543854}]
# [{'label': '5 stars', 'score': 0.517636775970459}]
# [{'label': '1 star', 'score': 0.5561489462852478}]
# [{'label': '5 stars', 'score': 0.5026639699935913}]
# [{'label': '5 stars', 'score': 0.40912339091300964}]
# [{'label': '5 stars', 'score': 0.47065064311027527}]
# [{'label': '1 star', 'score': 0.26136091351509094}]
# [{'label': '5 stars', 'score': 0.3942534029483795}]
# [{'label': '2 stars', 'score': 0.36317574977874756}]
# [{'label': '5 stars', 'score': 0.4419580101966858}]
# [{'label': '5 stars', 'score': 0.44927290081977844}]
# [{'label': '4 stars', 'score': 0.41961947083473206}]
# ...
# [{'label': '1 star', 'score': 0.25487765669822693}]
# [{'label': '2 stars', 'score': 0.22669990360736847}]
# [{'label': '1 star', 'score': 0.29577526450157166}]
# [{'label': '1 star', 'score': 0.23232047259807587}]
# [{'label': '1 star', 'score': 0.6454792618751526}]
# [{'label': '5 stars', 'score': 0.5201779007911682}]
# [{'label': '1 star', 'score': 0.6771826148033142}]
# [{'label': '2 stars', 'score': 0.30513831973075867}]
# [{'label': '5 stars', 'score': 0.3491738736629486}]
# [{'label': '2 stars', 'score': 0.3610839247703552}]
# [{'label': '1 star', 'score': 0.403982013463974}]
# [{'label': '5 stars', 'score': 0.7317976355552673}]
# [{'label': '1 star', 'score': 0.6116846799850464}]
# [{'label': '1 star', 'score': 0.6891714930534363}]
# [{'label': '5 stars', 'score': 0.5201303362846375}]
# [{'label': '1 star', 'score': 0.2510332465171814}]
# [{'label': '1 star', 'score': 0.6636490821838379}]
# [{'label': '3 stars', 'score': 0.2554873526096344}]
# [{'label': '1 star', 'score': 0.5640041828155518}]
# [{'label': '1 star', 'score': 0.6945396661758423}]
# [{'label': '1 star', 'score': 0.3327212929725647}]
# [{'label': '1 star', 'score': 0.6456500887870789}]
# [{'label': '4 stars', 'score': 0.31276795268058777}]
# [{'label': '5 stars', 'score': 0.6183645129203796}]
# [{'label': '1 star', 'score': 0.4607532024383545}]
# [{'label': '1 star', 'score': 0.6641649603843689}]
# [{'label': '1 star', 'score': 0.4173453450202942}]
# [{'label': '1 star', 'score': 0.2723267674446106}]
# [{'label': '5 stars', 'score': 0.43286144733428955}]
# [{'label': '5 stars', 'score': 0.35214754939079285}]
# [{'label': '1 star', 'score': 0.476043701171875}]
# [{'label': '5 stars', 'score': 0.3714604079723358}]
# [{'label': '5 stars', 'score': 0.35982680320739746}]
# [{'label': '5 stars', 'score': 0.3677557110786438}]
# [{'label': '5 stars', 'score': 0.3473620116710663}]
# [{'label': '4 stars', 'score': 0.3136942386627197}]
# [{'label': '5 stars', 'score': 0.4892982840538025}]
# [{'label': '1 star', 'score': 0.7250550985336304}]
# [{'label': '5 stars', 'score': 0.39720985293388367}]
# [{'label': '1 star', 'score': 0.3573402166366577}]
# [{'label': '3 stars', 'score': 0.41685429215431213}]
# [{'label': '2 stars', 'score': 0.2780442237854004}]
# [{'label': '5 stars', 'score': 0.4828594923019409}]
# [{'label': '5 stars', 'score': 0.45566174387931824}]
# [{'label': '4 stars', 'score': 0.35042163729667664}]
# [{'label': '2 stars', 'score': 0.2994846701622009}]
# [{'label': '1 star', 'score': 0.3763899505138397}]
# [{'label': '1 star', 'score': 0.5830994248390198}]
# [{'label': '5 stars', 'score': 0.5500762462615967}]
# [{'label': '5 stars', 'score': 0.40162280201911926}]
# [{'label': '1 star', 'score': 0.3825991153717041}]
# [{'label': '5 stars', 'score': 0.34020644426345825}]
# [{'label': '1 star', 'score': 0.36412864923477173}]
# [{'label': '4 stars', 'score': 0.32066717743873596}]
# [{'label': '1 star', 'score': 0.27586573362350464}]
# [{'label': '1 star', 'score': 0.22642549872398376}]
# [{'label': '1 star', 'score': 0.31970301270484924}]
# [{'label': '4 stars', 'score': 0.4128876030445099}]
# [{'label': '1 star', 'score': 0.7860525250434875}]
# [{'label': '4 stars', 'score': 0.450427770614624}]
# [{'label': '1 star', 'score': 0.318673312664032}]
# [{'label': '5 stars', 'score': 0.5150020122528076}]
# [{'label': '1 star', 'score': 0.6787192821502686}]
# [{'label': '1 star', 'score': 0.7325894236564636}]
# [{'label': '4 stars', 'score': 0.41525352001190186}]
# [{'label': '1 star', 'score': 0.5367009043693542}]
# [{'label': '1 star', 'score': 0.7019917368888855}]
# [{'label': '1 star', 'score': 0.606302797794342}]
# [{'label': '5 stars', 'score': 0.3245994448661804}]
# [{'label': '4 stars', 'score': 0.40215781331062317}]
# [{'label': '1 star', 'score': 0.3341892659664154}]
# [{'label': '4 stars', 'score': 0.24502545595169067}]
# [{'label': '3 stars', 'score': 0.23831923305988312}]
# [{'label': '5 stars', 'score': 0.6157963871955872}]
# [{'label': '1 star', 'score': 0.867430567741394}]
# [{'label': '4 stars', 'score': 0.2576211094856262}]
# [{'label': '4 stars', 'score': 0.4508022367954254}]
# [{'label': '5 stars', 'score': 0.547267735004425}]
# [{'label': '1 star', 'score': 0.3851902484893799}]
# [{'label': '1 star', 'score': 0.3443244695663452}]
# [{'label': '1 star', 'score': 0.4746507406234741}]
# [{'label': '4 stars', 'score': 0.2820180654525757}]
# [{'label': '5 stars', 'score': 0.3571016490459442}]
# [{'label': '1 star', 'score': 0.5848404765129089}]
# [{'label': '4 stars', 'score': 0.2437736690044403}]
# [{'label': '5 stars', 'score': 0.5578666925430298}]
# [{'label': '1 star', 'score': 0.7756608128547668}]
# [{'label': '1 star', 'score': 0.41146957874298096}]
# [{'label': '1 star', 'score': 0.4675709903240204}]
# [{'label': '5 stars', 'score': 0.646344780921936}]
# [{'label': '4 stars', 'score': 0.3806946575641632}]
# [{'label': '5 stars', 'score': 0.27876734733581543}]
# [{'label': '1 star', 'score': 0.7848926782608032}]
# [{'label': '5 stars', 'score': 0.4380764663219452}]
# [{'label': '1 star', 'score': 0.5273428559303284}]
# [{'label': '1 star', 'score': 0.4932325482368469}]
# [{'label': '1 star', 'score': 0.4292794466018677}]
# [{'label': '1 star', 'score': 0.3176843225955963}]
# [{'label': '5 stars', 'score': 0.400974839925766}]
# [{'label': '1 star', 'score': 0.3310950696468353}]
# [{'label': '5 stars', 'score': 0.36350947618484497}]
# [{'label': '1 star', 'score': 0.4315151870250702}]
# [{'label': '5 stars', 'score': 0.4585781991481781}]
# [{'label': '4 stars', 'score': 0.4279234707355499}]
# [{'label': '4 stars', 'score': 0.3584124743938446}]
# [{'label': '3 stars', 'score': 0.299335777759552}]
# [{'label': '1 star', 'score': 0.3139807879924774}]
# [{'label': '1 star', 'score': 0.42034077644348145}]
# [{'label': '1 star', 'score': 0.2877798080444336}]
# [{'label': '4 stars', 'score': 0.3498181402683258}]
# [{'label': '1 star', 'score': 0.28839728236198425}]
# [{'label': '4 stars', 'score': 0.3216847777366638}]
# [{'label': '5 stars', 'score': 0.38814687728881836}]
# [{'label': '5 stars', 'score': 0.7604910731315613}]
# [{'label': '5 stars', 'score': 0.35361918807029724}]
# [{'label': '5 stars', 'score': 0.575456440448761}]
# [{'label': '5 stars', 'score': 0.40699881315231323}]
# [{'label': '1 star', 'score': 0.6846923828125}]
# [{'label': '1 star', 'score': 0.7897515296936035}]
# [{'label': '1 star', 'score': 0.2557256817817688}]
# [{'label': '3 stars', 'score': 0.3581417202949524}]
# [{'label': '1 star', 'score': 0.39780738949775696}]
# [{'label': '4 stars', 'score': 0.3420834541320801}]
# [{'label': '2 stars', 'score': 0.3057185709476471}]
# [{'label': '5 stars', 'score': 0.661518931388855}]
# [{'label': '5 stars', 'score': 0.8368895053863525}]
# [{'label': '1 star', 'score': 0.3291630446910858}]
# [{'label': '1 star', 'score': 0.48807117342948914}]
# [{'label': '1 star', 'score': 0.49604082107543945}]
# [{'label': '4 stars', 'score': 0.2900952696800232}]
# [{'label': '1 star', 'score': 0.3516111671924591}]
# [{'label': '1 star', 'score': 0.25662702322006226}]
# [{'label': '1 star', 'score': 0.5799821615219116}]
# [{'label': '1 star', 'score': 0.41200703382492065}]
# [{'label': '1 star', 'score': 0.48522064089775085}]
# [{'label': '3 stars', 'score': 0.28231653571128845}]
# [{'label': '1 star', 'score': 0.42947009205818176}]
# [{'label': '5 stars', 'score': 0.3917948007583618}]
# [{'label': '4 stars', 'score': 0.32316091656684875}]
# [{'label': '3 stars', 'score': 0.3145367503166199}]
# [{'label': '5 stars', 'score': 0.3161683678627014}]
# [{'label': '1 star', 'score': 0.5728878974914551}]
# [{'label': '5 stars', 'score': 0.43561384081840515}]
# [{'label': '4 stars', 'score': 0.25290706753730774}]
# [{'label': '1 star', 'score': 0.36739230155944824}]
# [{'label': '1 star', 'score': 0.5302180051803589}]
# [{'label': '4 stars', 'score': 0.2908637523651123}]
# [{'label': '5 stars', 'score': 0.4701308012008667}]
# [{'label': '1 star', 'score': 0.7731397747993469}]
# [{'label': '5 stars', 'score': 0.5019323229789734}]
# [{'label': '4 stars', 'score': 0.3500818610191345}]
# [{'label': '3 stars', 'score': 0.39478880167007446}]
# [{'label': '5 stars', 'score': 0.6362425088882446}]
# [{'label': '4 stars', 'score': 0.36284664273262024}]
# [{'label': '1 star', 'score': 0.6307603716850281}]
# [{'label': '5 stars', 'score': 0.7386607527732849}]
# [{'label': '1 star', 'score': 0.38658592104911804}]
# [{'label': '5 stars', 'score': 0.31138649582862854}]
# [{'label': '4 stars', 'score': 0.3805655837059021}]
# [{'label': '1 star', 'score': 0.37141239643096924}]
# [{'label': '1 star', 'score': 0.3556533753871918}]
# [{'label': '1 star', 'score': 0.3076053559780121}]
# [{'label': '4 stars', 'score': 0.2746315896511078}]
# [{'label': '5 stars', 'score': 0.4262349009513855}]
# [{'label': '4 stars', 'score': 0.37874090671539307}]
# [{'label': '5 stars', 'score': 0.4730117917060852}]
# [{'label': '5 stars', 'score': 0.29612159729003906}]
# [{'label': '4 stars', 'score': 0.4547080099582672}]
# [{'label': '1 star', 'score': 0.4120348393917084}]
# [{'label': '1 star', 'score': 0.4223896265029907}]
# [{'label': '3 stars', 'score': 0.2683177888393402}]
# [{'label': '1 star', 'score': 0.6429214477539062}]
# [{'label': '4 stars', 'score': 0.33205482363700867}]
# [{'label': '4 stars', 'score': 0.44667014479637146}]
# [{'label': '2 stars', 'score': 0.37143227458000183}]
# [{'label': '1 star', 'score': 0.6409950852394104}]
# [{'label': '5 stars', 'score': 0.5416650772094727}]
# [{'label': '5 stars', 'score': 0.5531921982765198}]
# [{'label': '5 stars', 'score': 0.3479296565055847}]
# [{'label': '1 star', 'score': 0.44028785824775696}]
# [{'label': '3 stars', 'score': 0.24963638186454773}]
# [{'label': '5 stars', 'score': 0.38393861055374146}]
# [{'label': '5 stars', 'score': 0.4475899338722229}]
# [{'label': '5 stars', 'score': 0.31825798749923706}]
# [{'label': '2 stars', 'score': 0.2833057940006256}]
# [{'label': '1 star', 'score': 0.4471021294593811}]
# [{'label': '1 star', 'score': 0.4948570132255554}]
# [{'label': '4 stars', 'score': 0.30063676834106445}]
# [{'label': '5 stars', 'score': 0.36869797110557556}]
# [{'label': '5 stars', 'score': 0.30478793382644653}]
# [{'label': '5 stars', 'score': 0.6525930166244507}]
# [{'label': '1 star', 'score': 0.5984212160110474}]
# [{'label': '5 stars', 'score': 0.46719273924827576}]
# [{'label': '2 stars', 'score': 0.23691682517528534}]
# [{'label': '1 star', 'score': 0.2727102041244507}]
# [{'label': '1 star', 'score': 0.6079612374305725}]
# [{'label': '1 star', 'score': 0.5737563967704773}]
# [{'label': '1 star', 'score': 0.5860227346420288}]
# [{'label': '5 stars', 'score': 0.3961286246776581}]
# [{'label': '1 star', 'score': 0.7153535485267639}]
# [{'label': '1 star', 'score': 0.4504503607749939}]
# [{'label': '5 stars', 'score': 0.43624407052993774}]
# [{'label': '5 stars', 'score': 0.4979940950870514}]
# [{'label': '1 star', 'score': 0.3879392147064209}]
# [{'label': '5 stars', 'score': 0.42275041341781616}]
# [{'label': '5 stars', 'score': 0.27337703108787537}]
# [{'label': '4 stars', 'score': 0.3244369626045227}]
# [{'label': '1 star', 'score': 0.43634942173957825}]
# [{'label': '5 stars', 'score': 0.4981915354728699}]
# [{'label': '1 star', 'score': 0.5659413933753967}]
# [{'label': '1 star', 'score': 0.33406490087509155}]
# [{'label': '1 star', 'score': 0.6689003109931946}]
# [{'label': '4 stars', 'score': 0.3914783298969269}]
# [{'label': '5 stars', 'score': 0.5753129124641418}]
# [{'label': '3 stars', 'score': 0.30890029668807983}]
# [{'label': '1 star', 'score': 0.41149911284446716}]
# [{'label': '5 stars', 'score': 0.45673277974128723}]
# [{'label': '1 star', 'score': 0.48035749793052673}]
# [{'label': '1 star', 'score': 0.3298156261444092}]
# [{'label': '5 stars', 'score': 0.42942675948143005}]
# [{'label': '4 stars', 'score': 0.2981334328651428}]
# [{'label': '5 stars', 'score': 0.4437231719493866}]
# [{'label': '5 stars', 'score': 0.6381708383560181}]
# [{'label': '5 stars', 'score': 0.4928760826587677}]
# [{'label': '5 stars', 'score': 0.5096300840377808}]
# [{'label': '1 star', 'score': 0.27045899629592896}]
# [{'label': '5 stars', 'score': 0.42110809683799744}]
# [{'label': '5 stars', 'score': 0.29636627435684204}]
# [{'label': '5 stars', 'score': 0.24470780789852142}]
# [{'label': '5 stars', 'score': 0.3260730504989624}]
# [{'label': '1 star', 'score': 0.6192188858985901}]
# [{'label': '1 star', 'score': 0.33963459730148315}]
# [{'label': '1 star', 'score': 0.38536155223846436}]
# [{'label': '5 stars', 'score': 0.5373839735984802}]
# [{'label': '1 star', 'score': 0.48423051834106445}]
# [{'label': '5 stars', 'score': 0.4107491075992584}]
# [{'label': '4 stars', 'score': 0.36086341738700867}]
# [{'label': '1 star', 'score': 0.35215720534324646}]
# [{'label': '4 stars', 'score': 0.2847585380077362}]
# [{'label': '4 stars', 'score': 0.39555567502975464}]
# [{'label': '3 stars', 'score': 0.3602851927280426}]
# [{'label': '5 stars', 'score': 0.5025477409362793}]
# [{'label': '1 star', 'score': 0.5183020234107971}]
# [{'label': '5 stars', 'score': 0.5181239247322083}]
# [{'label': '1 star', 'score': 0.3390262722969055}]
# [{'label': '5 stars', 'score': 0.36287757754325867}]
# [{'label': '5 stars', 'score': 0.4347492754459381}]
# [{'label': '5 stars', 'score': 0.4847593903541565}]
# [{'label': '4 stars', 'score': 0.28747421503067017}]
# [{'label': '1 star', 'score': 0.6805964112281799}]
# [{'label': '5 stars', 'score': 0.48653218150138855}]
# [{'label': '5 stars', 'score': 0.4843617081642151}]
# [{'label': '5 stars', 'score': 0.5021061897277832}]
# [{'label': '1 star', 'score': 0.2706235945224762}]
# [{'label': '1 star', 'score': 0.724786102771759}]
# [{'label': '5 stars', 'score': 0.4927617311477661}]
# [{'label': '1 star', 'score': 0.5438242554664612}]
# [{'label': '1 star', 'score': 0.3879392147064209}]
# [{'label': '5 stars', 'score': 0.2805076539516449}]
# [{'label': '4 stars', 'score': 0.4207148849964142}]
# [{'label': '1 star', 'score': 0.673629105091095}]
# [{'label': '4 stars', 'score': 0.27352970838546753}]
# [{'label': '4 stars', 'score': 0.27288487553596497}]
# [{'label': '5 stars', 'score': 0.378630131483078}]
# [{'label': '1 star', 'score': 0.609279453754425}]
# [{'label': '5 stars', 'score': 0.4627150297164917}]
# [{'label': '5 stars', 'score': 0.6173692941665649}]
# [{'label': '1 star', 'score': 0.5194573998451233}]
# [{'label': '5 stars', 'score': 0.6618923544883728}]
# [{'label': '1 star', 'score': 0.513457179069519}]
# [{'label': '5 stars', 'score': 0.412154883146286}]
# [{'label': '1 star', 'score': 0.4193606674671173}]
# [{'label': '5 stars', 'score': 0.4881201386451721}]
# [{'label': '1 star', 'score': 0.7332051396369934}]
# [{'label': '2 stars', 'score': 0.37511828541755676}]
# [{'label': '4 stars', 'score': 0.38487929105758667}]
# [{'label': '1 star', 'score': 0.49377912282943726}]
# [{'label': '1 star', 'score': 0.5672903060913086}]
# [{'label': '4 stars', 'score': 0.24685311317443848}]
# [{'label': '1 star', 'score': 0.722565770149231}]
# [{'label': '4 stars', 'score': 0.3685104250907898}]
# [{'label': '4 stars', 'score': 0.3582940399646759}]
# [{'label': '1 star', 'score': 0.7448703050613403}]
# [{'label': '5 stars', 'score': 0.7036939859390259}]
# [{'label': '5 stars', 'score': 0.3733806014060974}]
# [{'label': '4 stars', 'score': 0.34765464067459106}]
# [{'label': '5 stars', 'score': 0.7044269442558289}]
# [{'label': '5 stars', 'score': 0.5897162556648254}]
# [{'label': '5 stars', 'score': 0.4514332115650177}]
# [{'label': '1 star', 'score': 0.7233763933181763}]
# [{'label': '5 stars', 'score': 0.7229030132293701}]
# [{'label': '4 stars', 'score': 0.2946213185787201}]
# [{'label': '1 star', 'score': 0.5714428424835205}]
# [{'label': '1 star', 'score': 0.3127642273902893}]
# [{'label': '1 star', 'score': 0.7491071820259094}]
# [{'label': '1 star', 'score': 0.575883686542511}]
# [{'label': '5 stars', 'score': 0.7612956762313843}]
# [{'label': '5 stars', 'score': 0.36210599541664124}]
# [{'label': '1 star', 'score': 0.2552981376647949}]
# [{'label': '1 star', 'score': 0.6788849830627441}]
# [{'label': '1 star', 'score': 0.68791663646698}]
# [{'label': '1 star', 'score': 0.3487592041492462}]
# [{'label': '1 star', 'score': 0.4710708260536194}]
# [{'label': '5 stars', 'score': 0.4937684237957001}]
# [{'label': '5 stars', 'score': 0.4587825536727905}]
# [{'label': '5 stars', 'score': 0.3553959131240845}]
# [{'label': '1 star', 'score': 0.44948479533195496}]
# [{'label': '1 star', 'score': 0.7621554136276245}]

# %%
bert_label = []
bert_score = []
for row in df['bert']:
  bert_label.append(row[0]['label'])
  bert_score.append(row[0]['score'])
df['bert_label'] = bert_label
df['bert_score'] = bert_score
df.to_excel('/content/drive/MyDrive/Equintel/esg_sentiment_data_updated.xlsx')

# %% [markdown]
# **Perform Sentiment Analysis using transformers making use of the Roberta Model**

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")
# Out:
# Downloading:   0%|          | 0.00/687 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/256 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
roberta = []
for str in df['title']: 
  roberta.append(classifier(str))
  #print(classifier(str))
df['roberta']=roberta

# %%
roberta_sentiment = []
roberta_score = []
for row in df['roberta']:
  if row[0]['label'] == 'POSITIVE':
    roberta_sentiment.append(1) 
  else:
    roberta_sentiment.append(0)
  roberta_score.append(row[0]['score'])
df['roberta_sentiment'] = roberta_sentiment
df['roberta_score'] = roberta_score
df.to_excel('/content/drive/MyDrive/Equintel/esg_sentiment_data_updated_081221.xlsx')

# %% [markdown]
# *Check the number of incorrect predictions* *

# %%
roberta_var_count = 0
for index,row in df.iterrows(): 
  if (row['automated_sentiment'] != row['roberta_sentiment']):
      roberta_var_count+=1

print(roberta_var_count)
# Out:
# 2650

# %% [markdown]
# **Perform Sentiment Analysis using Transformers making use of the FinBERT Model**

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis",model="ProsusAI/finbert")
finbert = []
for str in df['title']: 
  finbert.append(classifier(str))
  #print(classifier(str))
df['finbert']=finbert
# Out:
# Downloading:   0%|          | 0.00/758 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# **Update the predicted sentiment and score of the sentiment to the Excel sheet**

# %%
finbert_sentiment = []
finbert_score = []
for row in df['finbert']:
  if row[0]['label'] == 'positive':
    finbert_sentiment.append(1) 
  elif row[0]['label'] == 'neutral': 
    finbert_sentiment.append(0.5)
  else:
    finbert_sentiment.append(0)
  finbert_score.append(row[0]['score'])
df['finbert_sentiment'] = finbert_sentiment
df['finbert_score'] = finbert_score
df.to_excel('/content/drive/MyDrive/Equintel/esg_sentiment_data_updated_081221.xlsx')

# %% [markdown]
# ** Convert Neutral score of Finbert model to either positive or negative for easier comparison to the other two models**

# %%
# Convert Neutral score of Finbert model to either positive or negative for easier comparison to the other two models
finbert_sentiment_new = []

for row in df['finbert']:
  if row[0]['label'] == 'positive':
    finbert_sentiment_new.append(1) 
  elif (row[0]['label'] == 'neutral' and row[0]['score'] > 0.5): 
    finbert_sentiment_new.append(1)    
  elif (row[0]['label'] == 'neutral' and row[0]['score'] < 0.5):  
    finbert_sentiment_new.append(0) 
  else:
    finbert_sentiment_new.append(0)
 
df['finbert_sentiment_new'] = finbert_sentiment_new
df.to_excel('/content/drive/MyDrive/Equintel/esg_sentiment_data_updated.xlsx')

# %%
finbert_var_count = 0
for index,row in df.iterrows(): 
  if (row['automated_sentiment'] != row['finbert_sentiment_new']):
      finbert_var_count+=1

print(finbert_var_count)
